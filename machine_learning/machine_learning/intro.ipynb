# %% [markdown]
# # Intro To Machine Learning

# %% [markdown]
# - Data Selection
# Process tobe followed to create Data.
#
# - Data Processing<br>
#     Sklearn Link:https://scikit-learn.org/stable/modules/classes.html#module-sklearn.preprocessing
#     - Handling Missing Values
#     - Outlier Detection
#     - Feature Scaling
#         - https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html#sklearn.preprocessing.StandardScaler
#     - One-Hot Encoding
#         - Categorical Column
#         - Number of Categories > 2
#
# - Feature Selection:
# Use your domain knowledge to select only those features on which you want to build the model.
#
# - Model Selection
#
# - Model Training
#     - Training/Test Split(Mitigate Overfitting/Underfitting https://en.wikipedia.org/wiki/Overfitting)
#     - Model Fitting
#
#
# - Model Evaluation
#     - Classification Metrics
#     https://www.scikit-yb.org/en/latest/api/classifier/index.html
#         - Classification Report(https://en.wikipedia.org/wiki/Precision_and_recall)
#         - Confusion Matrix(https://en.wikipedia.org/wiki/Confusion_matrix)
#         - Precision Recall Curves
#     - Regression Metrics
#     - Clustering Metrics
#         - https://www.scikit-yb.org/en/latest/api/cluster/silhouette.html
#
# - Hyperparameter Tuning
#     - https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html
#     - https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.RandomizedSearchCV.html#sklearn.model_selection.RandomizedSearchCV
#
#
# - Prediction

# %% [markdown]
# # Supervised Machine Learning
# - Classification
# - Regression

# %% [markdown]
# ### Supervision
# observe and direct the execution of (a task or activity).

# %% [markdown]
# # Supervised ML Models
# - Linear Regression (Paramteric)
# - Logistic Regression (Paramteric)
# - Support Vector Machines (Paramteric)
# - Decision Trees and Random Forests (Non - Paramteric)
# - k-Nearest Neighbors(Non-Paramteric)
# - Neural networks(Paramteric)

# %% [markdown]
# # Unsupervised ML Models
# - Clustering: k-Means(https://scikit-learn.org/stable/modules/clustering.html#k-means)
# - Visualization and dimensionality reduction
# - Principal Component Analysis (PCA)

# %% [markdown]
# # Loss Functions
# - Regression
#     - MSE:https://en.wikipedia.org/wiki/Mean_squared_error
#     - MAE:https://en.wikipedia.org/wiki/Mean_absolute_error
# - Classification
#     - Cross Entropy Loss:https://en.wikipedia.org/wiki/Cross-entropy

# %% [markdown]
# ## Gradient Descent

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Decision Tree

# %% [markdown]
# |Day|	Outlook|	Temp.|	Humidity|	Wind|	Decision|
# |---|---|---|---|---|---|
# |1	|Sunny	|Hot	|High	|Weak	|No|
# |2	|Sunny	|Hot	|High	|Strong	|No|
# |3	|Overcast|	Hot	|High	|Weak	|Yes|
# |4	|Rain	|Mild|	High	|Weak	|Yes|
# |5	|Rain	|Cool|	Normal	|Weak|	Yes|
# |6	|Rain	|Cool|	Normal	|Strong|	No|
# |7	|Overcast|	Cool|	Normal|	Strong|	Yes|
# |8	|Sunny	|Mild|	High|	Weak|	No|
# |9	|Sunny	|Cool|	Normal	|Weak|	Yes|
# |10	|Rain	|Mild|	Normal|	Weak|	Yes|
# |11	|Sunny	|Mild|	Normal|	Strong|	Yes|
# |12	|Overcast|	Mild|	High|	Strong|	Yes|
# |13	|Overcast|	Hot|	Normal|	Weak|	Yes|
# |14	|Rain	|Mild|	High	|Strong|	No|

# %% [markdown]
# # References
# - https://sefiks.com/2018/08/27/a-step-by-step-cart-decision-tree-example/
# - https://www.geeksforgeeks.org/k-means-clustering-introduction/
# - https://en.wikipedia.org/wiki/Decision_tree_learning

# %% [markdown]
# # Data Preprocessing
# https://scikit-learn.org/stable/modules/preprocessing.html

# %% [markdown]
# ### Few Examples
# - Handling Missing Values
# - Outlier Detection
# - Feature Scaling
# - One-Hot Encoding

# %% [markdown]
# # Model Persist
# https://scikit-learn.org/stable/model_persistence.html

# %% [markdown]
# # Model Evaluation
# https://scikit-learn.org/stable/modules/model_evaluation.html

# %% [markdown]
# # Assignment (Exploration,Pipeline)
# - Data : https://www.kaggle.com/datasets/lakshmi25npathi/bike-sharing-dataset
# - Exploratory Data Analysis
# - Feature Engineering
# - Feature Selection
# - Column/Feature Transformation Pipeline
# - Build the Entire pipeline with model(Descion Tree Regressor)
# - Randomized Search
# - Evaluate the model - https://scikit-learn.org/stable/modules/generated/sklearn.metrics.r2_score.html#sklearn.metrics.r2_score
# - Save the best model using joblib
